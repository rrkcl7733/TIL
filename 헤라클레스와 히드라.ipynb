# %% [markdown]
# [![image-6.png](attachment:image-6.png)](https://www.acmicpc.net/problem/10205)

# %% [markdown]
# ---

# %%
for i in range(int(input())):
    print(f'Data Set {i + 1}:')
    n = int(input())
    for x in input():
        if x == 'c':
            n += 1
        else:
            n -= 1
    print(n)
    print()
