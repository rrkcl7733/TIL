# %% [markdown]
# [![image-8.png](attachment:image-8.png)](https://www.acmicpc.net/problem/5691)

# %% [markdown]
# ---

# %%
while 1:
    a, b = map(int, input().split())
    if not a:
        exit()
    print(2 * a - b)
