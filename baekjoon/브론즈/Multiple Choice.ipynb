# %% [markdown]
# [![image-6.png](attachment:image-6.png)](https://www.acmicpc.net/problem/6784)

# %% [markdown]
# ---

# %%
n = int(input())
a = [input() for _ in range(n)]
ans = 0
for i, x in enumerate([input() for _ in range(n)]):
    if a[i] == x:
        ans += 1
print(ans)
