# %% [markdown]
# [![image-5.png](attachment:image-5.png)](https://www.acmicpc.net/problem/10990)

# %% [markdown]
# ---

# %%
n = int(input())
for i in range(1, n + 1):
    if i == 1:
        print(' ' * (n - 1) + '*')
    else:
        print(' ' * (n - i) + '*' + ' ' * (2 * i - 3) + '*')

# %% [markdown]
# ---
