# %% [markdown]
# [![image-7.png](attachment:image-7.png)](https://www.acmicpc.net/problem/17598)

# %% [markdown]
# ---

# %%
print('Tiger' if sum(input()[0] == 'T' for _ in range(9)) > 4 else 'Lion')

# %% [markdown]
# ---
