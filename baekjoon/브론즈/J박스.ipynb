# %% [markdown]
# [![image-12.png](attachment:image-12.png)](https://www.acmicpc.net/problem/5354)

# %% [markdown]
# ---

# %%
for _ in range(int(input())):
    n = int(input())
    for i in range(n):
        if 0 < i < n - 1:
            print('#' + 'J' * (n - 2) + '#')
        else:
            print('#' * n)
    print()

# %% [markdown]
# ---
