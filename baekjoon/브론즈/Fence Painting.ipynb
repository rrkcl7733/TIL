# %% [markdown]
# [![image-9.png](attachment:image-9.png)](https://www.acmicpc.net/problem/11970)

# %% [markdown]
# ---

# %%
x = [0] * 101
a, b = map(int, input().split())
c, d = map(int, input().split())
for i in range(a, b):
    x[i] = 1
for i in range(c, d):
    x[i] = 1
print(x.count(1))
