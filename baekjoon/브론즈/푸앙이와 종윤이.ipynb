# %% [markdown]
# [![image-2.png](attachment:image-2.png)](https://www.acmicpc.net/problem/25591)

# %% [markdown]
# ---

# %%
x, y = map(int, input().split())
a, b = 100 - x, 100 - y
c, d = 100 - (a + b), a * b
x *= y
q, w = x // 100, x % 100
print(a, b, c, d, q - c, w)
print(q, w)
