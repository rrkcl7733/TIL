# %% [markdown]
# [![image-8.png](attachment:image-8.png)](https://www.acmicpc.net/problem/7595)

# %% [markdown]
# ---

# %%
while 1:
    n = int(input())
    if not n:
        exit()
    for i in range(1, n + 1):
        print('*' * i)
