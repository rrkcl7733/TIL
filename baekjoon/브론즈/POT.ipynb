# %% [markdown]
# [![image-7.png](attachment:image-7.png)](https://www.acmicpc.net/problem/11772)

# %% [markdown]
# ---

# %%
n = 0
for _ in range(int(input())):
    a = input()
    n += int(a[:-1]) ** int(a[-1])
print(n)

# %% [markdown]
# ---
