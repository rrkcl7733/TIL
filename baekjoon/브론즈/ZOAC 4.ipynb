# %% [markdown]
# [![image-3.png](attachment:image-3.png)](https://www.acmicpc.net/problem/23971)

# %%
from math import ceil

h, w, n, m = map(int, input().split())
print(ceil(h / (n + 1)) * ceil(w / (m + 1)))

# %% [markdown]
# ---
