# %% [markdown]
# [![image-9.png](attachment:image-9.png)](https://www.acmicpc.net/problem/9366)

# %% [markdown]
# ---

# %%
for i in range(int(input())):
    a, b, c = sorted(list(map(int, input().split())))
    print(f'Case #{i + 1}: {"equilateral" if a == c else "invalid!" if a + b <= c else "isosceles" if a == b or b == c else "scalene"}')
