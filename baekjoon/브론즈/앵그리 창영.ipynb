# %% [markdown]
# [![image-6.png](attachment:image-6.png)](https://www.acmicpc.net/problem/3034)

# %% [markdown]
# ---

# %%
n, x, y = map(int, input().split())
for _ in range(n):
    print('DA' if int(input()) <= (x ** 2 + y ** 2) ** .5 else 'NE')

# %% [markdown]
# ---
