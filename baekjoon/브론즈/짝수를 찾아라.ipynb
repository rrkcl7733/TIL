# %% [markdown]
# [![image-7.png](attachment:image-7.png)](https://www.acmicpc.net/problem/3058)

# %% [markdown]
# ---

# %%
for _ in range(int(input())):
    x, c = 0, 100
    for i in list(map(int, input().split())):
        if not i % 2:
            x += i
            c = min(c, i)
    print(x, c)

# %% [markdown]
# ---
