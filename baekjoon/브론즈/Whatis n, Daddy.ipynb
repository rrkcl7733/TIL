# %% [markdown]
# [![image-5.png](attachment:image-5.png)](https://www.acmicpc.net/problem/6794)

# %% [markdown]
# ---

# %%
a = int(input())
print(sum([1 if i + j == a else 0 for i in range(6) for j in range(i, 6)]))
# Out:
# 10
# 1

# %% [markdown]
# ---
