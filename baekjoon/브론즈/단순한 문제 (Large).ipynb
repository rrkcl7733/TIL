# %% [markdown]
# [![image-6.png](attachment:image-6.png)](https://www.acmicpc.net/problem/25487)

# %% [markdown]
# ---

# %%
import sys
input = sys.stdin.readline


for _ in range(int(input())):
    print(min(map(int, input().split())))

# %% [markdown]
# ---

# %% [markdown]
# ### 테케가 60만개라서 import sys 로 입력받지 않으면 무조건 시간초과
