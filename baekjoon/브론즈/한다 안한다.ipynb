# %% [markdown]
# [![image-8.png](attachment:image-8.png)](https://www.acmicpc.net/problem/5789)

# %% [markdown]
# ---

# %%
for _ in range(int(input())):
    a = input()
    n = len(a) // 2
    print('Do-it' if a[n - 1] == a[n] else 'Do-it-Not')
