# %% [markdown]
# [![image-7.png](attachment:image-7.png)](https://www.acmicpc.net/problem/9310)

# %% [markdown]
# ---

# %%
while 1:
    n = int(input())
    if not n:
        exit()
    a, b, c = list(map(int, input().split()))
    print(a * ((b // a) ** n - 1) // (b // a - 1) if c - b != b - a else n * (2 * a + (n - 1) * (b - a)) // 2)
