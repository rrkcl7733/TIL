# %% [markdown]
# [![image-2.png](attachment:image-2.png)](https://www.acmicpc.net/problem/4880)

# %% [markdown]
# ---

# %%
while 1:
    a, b, c = map(int, input().split())
    if (a, b, c) == (0, 0, 0):
        exit()
    print(f'AP {2 * c - b}' if 2 * b == a + c else f'GP {c ** 2 // b}')
