# %% [markdown]
# [![image-13.png](attachment:image-13.png)](https://www.acmicpc.net/problem/4504)

# %% [markdown]
# ---

# %%
n = int(input())
while 1:
    a = int(input())
    if not a:
        exit()
    print(f'{a} is NOT a multiple of {n}.' if a % n else f'{a} is a multiple of {n}.')

# %% [markdown]
# ---
