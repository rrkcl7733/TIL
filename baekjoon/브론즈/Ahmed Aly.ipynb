# %% [markdown]
# [![image-5.png](attachment:image-5.png)](https://www.acmicpc.net/problem/10698)

# %% [markdown]
# ---

# %%
for i in range(int(input())):
    print(f'Case {i + 1}: ', end='')
    a, n = input().split(" = ")
    print('YES' if eval(a) == int(n) else 'NO')
