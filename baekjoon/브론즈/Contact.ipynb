# %% [markdown]
# [![image-6.png](attachment:image-6.png)](https://www.acmicpc.net/problem/1013)

# %% [markdown]
# ---

# %%
import re

for _ in range(int(input())):
    p = re.compile('(100+1+|01)+')
    m = p.fullmatch(input())
    print('YES' if m else 'NO')
