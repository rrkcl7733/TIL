# %% [markdown]
# [![image-8.png](attachment:image-8.png)](https://www.acmicpc.net/problem/25881)

# %% [markdown]
# ---

# %%
n, m = map(int, input().split())
for _ in range(int(input())):
    a = int(input())
    print(f'{a} {a * n if a <= 1000 else (a - 1000) * m + 1000 * n}')
