# %% [markdown]
# [![image-8.png](attachment:image-8.png)](https://www.acmicpc.net/problem/25858)

# %% [markdown]
# ---

# %%
n, a = map(int, input().split())
x = [int(input()) for _ in range(n)]
p = a // sum(x)
for i in x:
    print(i * p)
