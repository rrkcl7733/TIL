# %% [markdown]
# [![image-2.png](attachment:image-2.png)](https://www.acmicpc.net/problem/23348)

# %% [markdown]
# ---

# %%
a, b, c = map(int, input().split())
x = 0
for _ in range(int(input())):
    team = 0
    for _ in range(3):
        aa, bb, cc = map(int, input().split())
        team += aa * a + bb * b + cc * c
    x = max(x, team)
print(x)
