# %% [markdown]
# [![image-9.png](attachment:image-9.png)](https://www.acmicpc.net/problem/4740)

# %% [markdown]
# ---

# %%
while 1:
    a = input()
    if a == '***':
        exit()
    print(a[::-1])

# %% [markdown]
# ---
