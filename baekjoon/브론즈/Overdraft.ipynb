# %% [markdown]
# [![image-6.png](attachment:image-6.png)](https://www.acmicpc.net/problem/24609)

# %% [markdown]
# ---

# %%
t = x = 0
for _ in range(int(input())):
    t += int(input())
    if t < 0:
        x += -t
        t = 0
print(x)

# %% [markdown]
# ---
