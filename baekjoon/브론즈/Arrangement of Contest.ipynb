# %% [markdown]
# [![image-7.png](attachment:image-7.png)](https://www.acmicpc.net/problem/9443)

# %% [markdown]
# ---

# %%
n = int(input())
x, i = 0, 65
for t in sorted([input()[0] for _ in range(n)]):
    if ord(t) == i:
        x += 1
        i += 1
print(x)
