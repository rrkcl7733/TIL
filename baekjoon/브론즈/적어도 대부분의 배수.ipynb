# %% [markdown]
# [![image-2.png](attachment:image-2.png)](https://www.acmicpc.net/problem/1145)

# %% [markdown]
# ---

# %%
from itertools import combinations
import math

a = list(map(int, input().split()))
x = 1e9
for i in list(combinations(a, 3)):
    x = min(x, math.lcm(i[0], i[1], i[2]))

print(x)
