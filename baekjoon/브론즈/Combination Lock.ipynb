# %% [markdown]
# [![image-7.png](attachment:image-7.png)](https://www.acmicpc.net/problem/4117)

# %% [markdown]
# ---

# %%
while 1:
    n, t1, t2, t3 = map(int, input().split())
    if (n, t1, t2, t3) == (0, 0, 0, 0):
        exit()
    print(4 * n + (t2 - t1 + n) % n + (t2 - t3 + n) % n - 1)

# %% [markdown]
# ---
