# %% [markdown]
# [![image-8.png](attachment:image-8.png)](https://www.acmicpc.net/problem/2997)

# %% [markdown]
# ---

# %%
a, b, c = sorted(map(int, input().split()))
x, y = b - a, c - b
print(c + x if x == y else b - y if x > y else c - x)

# %% [markdown]
# ---
