# %% [markdown]
# [![image-12.png](attachment:image-12.png)](https://www.acmicpc.net/problem/5613)

# %% [markdown]
# ---

# %%
a = ''
while 1:
    x = input()
    if x == '=':
        print(a)
        exit()
    elif x.isdigit():
        a = str(eval(a + x))
    elif x == '/':
        a += '//'
    else:
        a += x

# %% [markdown]
# ---
