# %% [markdown]
# [![image-10.png](attachment:image-10.png)](https://www.acmicpc.net/problem/5612)

# %% [markdown]
# ---

# %%
n = int(input())
ans = x = int(input())
for _ in range(n):
    a, b = map(int ,input().split())
    x += a - b
    if x < 0:
        print(0)
        exit()
    ans = max(ans, x)
print(ans)

# %% [markdown]
# ---
