# %% [markdown]
# [![image-6.png](attachment:image-6.png)](https://www.acmicpc.net/problem/9838)

# %% [markdown]
# ---

# %%
n = int(input())
a = [0] * n
for i in range(n):
    a[int(input()) - 1] = i + 1
print(*a, sep='\n')
