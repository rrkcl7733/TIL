# %% [markdown]
# [![image-3.png](attachment:image-3.png)](https://www.acmicpc.net/problem/9501)

# %% [markdown]
# ---

# %%
for _ in range(int(input())):
    n, d = map(int, input().split())
    x = 0
    for _ in range(n):
        a, b, c = map(int, input().split())
        if a * (b / c) >= d:
            x += 1
    print(x)
