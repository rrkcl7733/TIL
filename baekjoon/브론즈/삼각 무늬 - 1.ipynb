# %% [markdown]
# [![image-8.png](attachment:image-8.png)](https://www.acmicpc.net/problem/11320)

# %% [markdown]
# ---

# %%
for _ in range(int(input())):
    a, b = map(int, input().split())
    print((a//b)**2)
