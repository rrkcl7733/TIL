# %% [markdown]
# [![image-8.png](attachment:image-8.png)](https://www.acmicpc.net/problem/9493)

# %% [markdown]
# ---

# %%
while 1:
    m, a, b = map(int, input().split())
    if (m, a, b) == (0, 0, 0):
        exit()
    x = round((m / a - m / b) * 3600)
    print(f'{x // 3600:d}:{(x % 3600) // 60:02d}:{x % 60:02d}')
