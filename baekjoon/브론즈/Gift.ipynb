# %% [markdown]
# [![image-5.png](attachment:image-5.png)](https://www.acmicpc.net/problem/9848)

# %% [markdown]
# ---

# %%
x = 0
n, k = map(int, input().split())
a = int(input())
for _ in range(n - 1):
    b = int(input())
    if a - b >= k:
        x += 1
    a = b
print(x)

# %% [markdown]
# ---
