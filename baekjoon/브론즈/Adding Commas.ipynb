# %% [markdown]
# [![image-6.png](attachment:image-6.png)](https://www.acmicpc.net/problem/5949)

# %% [markdown]
# ---

# %%
a = ''
for i, j in enumerate(input()[::-1]):
    if i // 3 and not i % 3:
        a = ',' + a
    a = j + a
print(a)
