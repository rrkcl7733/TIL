# %% [markdown]
# [![image-8.png](attachment:image-8.png)](https://www.acmicpc.net/problem/10991)

# %% [markdown]
# ---

# %%
n = int(input())
for i in range(1, n + 1):
    print(' ' * (n - i), end='')
    for j in range(i):
        print('*', end=' ')
    print()

# %% [markdown]
# ---
