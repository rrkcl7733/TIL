# %% [markdown]
# [![image-4.png](attachment:image-4.png)](https://www.acmicpc.net/problem/2985)

# %% [markdown]
# ---

# %%
q = ['+', '-', '*', '/', '==']


def f(x):
    if eval(x):
        x = x.replace('==', '=')
        print(x)
        exit()


a, b, c = input().split()
for i in range(4):
    f(a + q[i] + b + q[4] + c)
    f(a + q[4] + b + q[i] + c)
# Out:
# 5 15 3
# 5=15/3

# %% [markdown]
# ---
