# %% [markdown]
# [![image-3.png](attachment:image-3.png)](https://www.acmicpc.net/problem/5666)

# %% [markdown]
# ---

# %%
while 1:
    try:
        a, b = map(int, input().split())
        print(f'{round(a / b, 2):.2f}')
    except:
        exit()

# %% [markdown]
# ---
