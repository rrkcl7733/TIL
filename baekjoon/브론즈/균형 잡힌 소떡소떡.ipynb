# %% [markdown]
# [![image-4.png](attachment:image-4.png)](https://www.acmicpc.net/problem/25641)

# %% [markdown]
# ---

# %%
n = int(input())
a = input()
for i in range(n):
    if a[i:].count('s') == a[i:].count('t'):
        print(a[i:])
        exit()
