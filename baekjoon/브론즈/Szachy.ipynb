# %% [markdown]
# [![image-6.png](attachment:image-6.png)](https://www.acmicpc.net/problem/8725)

# %% [markdown]
# ---

# %%
a = 0
for _ in range(int(input())):
    a += max(0, max(list(map(int, input().split()))))
print(a)
