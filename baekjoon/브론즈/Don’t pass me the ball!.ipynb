# %% [markdown]
# [![image-5.png](attachment:image-5.png)](https://www.acmicpc.net/problem/6768)

# %% [markdown]
# ---

# %%
from itertools import combinations

n = int(input())
print(len(list(combinations(range(n - 1), 3))))
