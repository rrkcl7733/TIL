# %% [markdown]
# [![image-5.png](attachment:image-5.png)](https://www.acmicpc.net/problem/4459)

# %% [markdown]
# ---

# %%
a = {}
for i in range(1, int(input()) + 1):
    a[i] = input()
for _ in range(int(input())):
    x = int(input())
    print(f'Rule {x}: {a.get(x, "No such rule")}')

# %% [markdown]
# ---
