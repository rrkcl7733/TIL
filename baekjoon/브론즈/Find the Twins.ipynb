# %% [markdown]
# [![image-8.png](attachment:image-8.png)](https://www.acmicpc.net/problem/25932)

# %% [markdown]
# ---

# %%
for _ in range(int(input())):
    a = list(map(int, input().split()))
    print(*a)
    print('both' if a.count(17) and a.count(18) else 'mack' if a.count(18) else 'zack' if a.count(17) else 'none')
    print()
