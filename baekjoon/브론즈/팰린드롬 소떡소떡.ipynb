# %% [markdown]
# [![image-5.png](attachment:image-5.png)](https://www.acmicpc.net/problem/25630)

# %% [markdown]
# ---

# %%
n = int(input())
a, t = input(), 0
if n % 2:
    n //= 2
    x, y = a[:n], a[n + 1:][::-1]
else:
    n //= 2
    x, y = a[:n], a[n:][::-1]
for i in range(n):
    if x[i] != y[i]:
        t += 1
print(t)
