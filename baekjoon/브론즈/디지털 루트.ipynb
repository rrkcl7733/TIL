# %% [markdown]
# [![image-11.png](attachment:image-11.png)](https://www.acmicpc.net/problem/6378)

# %% [markdown]
# ---

# %%
while 1:
    n = input()
    if n == '0':
        exit()
    while n // 10:
        n = sum(map(int, list(str(n))))
    print(n)

# %% [markdown]
# ---
