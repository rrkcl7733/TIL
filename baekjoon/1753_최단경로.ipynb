# %% [markdown]
# [![image-10.png](attachment:image-10.png)](https://www.acmicpc.net/problem/1753)

# %%
import heapq
import sys
input = sys.stdin.readline
inf = int(1e9)


def dijkstra(start):
    q = []
    heapq.heappush(q, (0, start))    # (거리, 노드)
    distance[start] = 0
    while q:
        dist, now = heapq.heappop(q)
        if distance[now] < dist:     # 방문한 적 있었니?
            continue
        for i in graph[now]:
            cost = dist + i[1]     # 새로 발견한 길이 더 짧다면
            if cost < distance[i[0]]:
                distance[i[0]] = cost
                heapq.heappush(q, (cost, i[0]))


n, e = map(int, input().split())
start = int(input())
graph = [[] for _ in range(n + 1)]
distance = [inf] * (n + 1)
for _ in range(e):
    a, b, c = map(int, input().split())
    graph[a].append((b, c))
dijkstra(start)
# 여기까지 기본 다익스트라 알고리즘
for i in range(1, n + 1):
    print('INF' if distance[i] == inf else distance[i])

# %% [markdown]
# ---

# %% [markdown]
# 우선순위 큐를 활용한 기본적인 다익스트라 알고리즘.
