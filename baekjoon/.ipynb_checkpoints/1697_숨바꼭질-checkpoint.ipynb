# %% [markdown]
# ![image-5.png](attachment:image-5.png)

# %%
from collections import deque

def bfs(n):
    visited[n] = 1
    q = deque()
    q.append(n)
    while q:
        x = q.popleft()
        hubo = [x + 1, x - 1, 2 * x]
        for i in hubo:
            if 0 <= i <= 2 * big and visited[i] == 0:
                q.append(i)
                visited[i] = visited[x] + 1
        if visited[k]:
            return visited[k] - 1


n, k = map(int, input().split())
big = max(n, k)
visited = [0] * (2 * big + 1)
print(bfs(n))

# %% [markdown]
# ---

# %% [markdown]
# 일차원 bfs 풀이.<br>
# hubo 는 총 3가지. 1칸 앞 or 1칸 뒤 or 2배<br>
# 무조건 동생이 있는 곳에 도달 가능 (불가능한 경우가 없는 것 감안한 코딩)
# bfs 로 풀릴까 했는데 visited 에 적힌 숫자가 작은데다가 덮어쓰기 하지 않아서 최소값 구할 수 있겠다 생각함.<br><br>
# 틀린 반례가 `10 19` / `5 19` 였는데, 앞질러 간 후에 다시 돌아오는 경우도 있었음(이를 구현위해선 넉넉한 visited 배열 필요. `big + 1   ---->   2 * big + 1` 로 수정 후 정답
