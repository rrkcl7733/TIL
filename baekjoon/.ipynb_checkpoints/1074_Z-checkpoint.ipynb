# %% [markdown]
# [![image-11.png](attachment:image-11.png)](https://www.acmicpc.net/problem/1074)

# %%
N, r, c = map(int, input().split())


def sol(N, r, c):
    if N == 0:
        return 0
    return 2 * (r % 2) + (c % 2) + 4 * sol(N - 1, r // 2, c // 2)


print(sol(N, r, c))

# %% [markdown]
# ---

# %% [markdown]
# https://ggasoon2.tistory.com/11<br>
# 이 분 풀이를 참고했는데요. 재귀를 층마다 분할해서 보는 방법을 배웠습니다
