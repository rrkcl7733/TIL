# %% [markdown]
# [![image-11.png](attachment:image-11.png)](https://www.acmicpc.net/problem/1011)

# %%
for _ in range(int(input())):
    x, y = map(int, input().split())
    print(int(((y - x) * 4 - 3) ** .5))

# %% [markdown]
# ---

# %% [markdown]
# 직접 크기를 늘려보며 규칙성을 찾는 데 결과는 간단하게 나옴.<br>
# 그러나 과정이 매우 어려움...
